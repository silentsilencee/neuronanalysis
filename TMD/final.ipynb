# %%
import tmd
from tmd.view import view, plot
import os

# %%
distance_stepped = []
distance_horizontal = []

# %%
filename_base = '/Users/shivam/Desktop/neuron_analysos/analysis/TMD/TMD/tests/data/valid/sample.swc'
neu_base = tmd.io.load_neuron(filename_base)
tree_base = neu_base.neurites[0]
ph1_base = tmd.methods.get_persistence_diagram(tree_base)
ph_neu_base = tmd.methods.get_ph_neuron(neu_base)
view.neuron(neu_base)
ph_all_base = tmd.methods.get_ph_neuron(neu_base, neurite_type='all')
plot.barcode(ph_all_base)
# Out:
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:146: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = fig.add_subplot(subplot, **params)
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:146: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = fig.add_subplot(subplot, **params)
# (<Figure size 432x288 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x1281cb4c0>)

# %%
directory = os.fsencode("/Users/shivam/Desktop/neuron_analysos/analysis/TMD/cells_being_used")

# %%
mapping = {'L1_DAC_bNAC219_1': 'bbp001',
 'L1_HAC_bNAC219_1': 'bbp004',
 'L1_NGC-DA_bNAC219_1': 'bbp007',
 'L1_SLAC_bNAC219_1': 'bbp012',
 'L23_BP_bNAC219_1': 'bbp017',
 'L23_BTC_bNAC219_1': 'bbp023',
 'L23_DBC_bNAC219_1': 'bbp031',
 'L23_LBC_bNAC219_1': 'bbp034',
 'L23_MC_bNAC219_1': 'bbp040',
 'L23_NBC_bNAC219_1': 'bbp045',
 'L23_NGC_bNAC219_1': 'bbp050',
 'L23_SBC_bNAC219_1': 'bbp055',
 'L4_BP_bNAC219_1': 'bbp060',
 'L4_DBC_bNAC219_1': 'bbp075',
 'L4_MC_bNAC219_1': 'bbp086',
 'L4_NGC_bNAC219_1': 'bbp094',
 'L4_SBC_bNAC219_1': 'bbp099',
 'L5_BP_bNAC219_1': 'bbp106',
 'L5_DBC_bNAC219_1': 'bbp118',
 'L5_NGC_bNAC219_1': 'bbp145',
 'L5_SBC_bNAC219_1': 'bbp149',
 'L6_BP_bNAC219_1': 'bbp159',
 'L6_DBC_bNAC219_1': 'bbp171',
 'L6_LBC_bNAC219_1': 'bbp179',
 'L6_MC_bNAC219_1': 'bbp185',
 'L6_NGC_bNAC219_1': 'bbp198',
 'L6_SBC_bNAC219_1': 'bbp202',
 'L4_BTC_bSTUT213_1': 'bbp066',
 'L4_DBC_bSTUT213_1': 'bbp076',
 'L5_DBC_bSTUT213_1': 'bbp119',
 'L5_MC_bSTUT213_1': 'bbp132',
 'L5_NBC_bSTUT213_1': 'bbp139',
 'L6_DBC_bSTUT213_1': 'bbp172',
 'L6_LBC_bSTUT213_1': 'bbp180',
 'L6_MC_bSTUT213_1': 'bbp186',
 'L6_NBC_bSTUT213_1': 'bbp192',
 'L1_NGC-DA_cACint209_1': 'bbp008',
 'L1_SLAC_cACint209_1': 'bbp013',
 'L23_BP_cACint209_1': 'bbp018',
 'L23_BTC_cACint209_1': 'bbp024',
 'L23_ChC_cACint209_1': 'bbp026',
 'L23_DBC_cACint209_1': 'bbp032',
 'L23_LBC_cACint209_1': 'bbp035',
 'L23_MC_cACint209_1': 'bbp041',
 'L23_NBC_cACint209_1': 'bbp046',
 'L23_NGC_cACint209_1': 'bbp051',
 'L23_SBC_cACint209_1': 'bbp056',
 'L4_BP_cACint209_1': 'bbp061',
 'L4_BTC_cACint209_1': 'bbp067',
 'L4_ChC_cACint209_1': 'bbp070',
 'L4_DBC_cACint209_1': 'bbp077',
 'L4_LBC_cACint209_1': 'bbp080',
 'L4_MC_cACint209_1': 'bbp087',
 'L4_NBC_cACint209_1': 'bbp090',
 'L4_NGC_cACint209_1': 'bbp095',
 'L4_SBC_cACint209_1': 'bbp100',
 'L5_BP_cACint209_1': 'bbp107',
 'L5_BTC_cACint209_1': 'bbp111',
 'L5_ChC_cACint209_1': 'bbp113',
 'L5_DBC_cACint209_1': 'bbp120',
 'L5_LBC_cACint209_1': 'bbp124',
 'L5_MC_cACint209_1': 'bbp133',
 'L5_NBC_cACint209_1': 'bbp140',
 'L5_NGC_cACint209_1': 'bbp146',
 'L5_SBC_cACint209_1': 'bbp150',
 'L6_BP_cACint209_1': 'bbp160',
 'L6_BTC_cACint209_1': 'bbp164',
 'L6_ChC_cACint209_1': 'bbp166',
 'L6_DBC_cACint209_1': 'bbp173',
 'L6_MC_cACint209_1': 'bbp187',
 'L6_NBC_cACint209_1': 'bbp193',
 'L6_NGC_cACint209_1': 'bbp199',
 'L6_SBC_cACint209_1': 'bbp203',
 'L23_PC_cADpyr229_1': 'bbp054',
 'L4_PC_cADpyr230_1': 'bbp098',
 'L4_SP_cADpyr230_1': 'bbp102',
 'L5_STPC_cADpyr232_1': 'bbp152',
 'L5_TTPC1_cADpyr232_1': 'bbp153',
 'L5_TTPC2_cADpyr232_1': 'bbp154',
 'L5_UTPC_cADpyr232_1': 'bbp155',
 'L6_BPC_cADpyr231_1': 'bbp156',
 'L6_IPC_cADpyr231_1': 'bbp176',
 'L6_TPC_L1_cADpyr231_1': 'bbp205',
 'L6_TPC_L4_cADpyr231_1': 'bbp206',
 'L6_UTPC_cADpyr231_1': 'bbp207',
 'L1_HAC_cIR216_1': 'bbp005',
 'L23_NBC_cIR216_1': 'bbp047',
 'L4_DBC_cIR216_1': 'bbp078',
 'L4_NBC_cIR216_1': 'bbp091',
 'L5_DBC_cIR216_1': 'bbp121',
 'L5_LBC_cIR216_1': 'bbp125',
 'L5_NBC_cIR216_1': 'bbp141',
 'L6_DBC_cIR216_1': 'bbp174',
 'L6_MC_cIR216_1': 'bbp188',
 'L6_NBC_cIR216_1': 'bbp194',
 'L1_DAC_cNAC187_1': 'bbp002',
 'L1_DLAC_cNAC187_1': 'bbp003',
 'L1_HAC_cNAC187_1': 'bbp006',
 'L1_NGC-DA_cNAC187_1': 'bbp009',
 'L1_NGC-SA_cNAC187_1': 'bbp011',
 'L1_SLAC_cNAC187_1': 'bbp014',
 'L23_BP_cNAC187_1': 'bbp019',
 'L23_BTC_cNAC187_1': 'bbp025',
 'L23_ChC_cNAC187_1': 'bbp027',
 'L23_LBC_cNAC187_1': 'bbp036',
 'L23_MC_cNAC187_1': 'bbp042',
 'L23_NBC_cNAC187_1': 'bbp048',
 'L23_NGC_cNAC187_1': 'bbp052',
 'L4_BP_cNAC187_1': 'bbp062',
 'L4_BTC_cNAC187_1': 'bbp068',
 'L4_ChC_cNAC187_1': 'bbp071',
 'L4_DBC_cNAC187_1': 'bbp079',
 'L4_LBC_cNAC187_1': 'bbp081',
 'L4_MC_cNAC187_1': 'bbp088',
 'L4_NBC_cNAC187_1': 'bbp092',
 'L4_NGC_cNAC187_1': 'bbp096',
 'L5_BP_cNAC187_1': 'bbp108',
 'L5_BTC_cNAC187_1': 'bbp112',
 'L5_ChC_cNAC187_1': 'bbp114',
 'L5_DBC_cNAC187_1': 'bbp122',
 'L5_LBC_cNAC187_1': 'bbp126',
 'L5_MC_cNAC187_1': 'bbp134',
 'L5_NBC_cNAC187_1': 'bbp142',
 'L5_NGC_cNAC187_1': 'bbp147',
 'L6_BP_cNAC187_1': 'bbp161',
 'L6_BTC_cNAC187_1': 'bbp165',
 'L6_ChC_cNAC187_1': 'bbp167',
 'L6_DBC_cNAC187_1': 'bbp175',
 'L6_LBC_cNAC187_1': 'bbp181',
 'L6_MC_cNAC187_1': 'bbp189',
 'L6_NBC_cNAC187_1': 'bbp195',
 'L6_NGC_cNAC187_1': 'bbp200',
 'L1_NGC-DA_cSTUT189_1': 'bbp010',
 'L23_LBC_cSTUT189_1': 'bbp037',
 'L23_NGC_cSTUT189_1': 'bbp053',
 'L4_LBC_cSTUT189_1': 'bbp082',
 'L4_NGC_cSTUT189_1': 'bbp097',
 'L5_LBC_cSTUT189_1': 'bbp127',
 'L5_MC_cSTUT189_1': 'bbp135',
 'L5_NBC_cSTUT189_1': 'bbp143',
 'L5_NGC_cSTUT189_1': 'bbp148',
 'L6_LBC_cSTUT189_1': 'bbp182',
 'L6_NBC_cSTUT189_1': 'bbp196',
 'L6_NGC_cSTUT189_1': 'bbp201',
 'L23_ChC_dNAC222_1': 'bbp028',
 'L23_LBC_dNAC222_1': 'bbp038',
 'L23_MC_dNAC222_1': 'bbp043',
 'L23_NBC_dNAC222_1': 'bbp049',
 'L23_SBC_dNAC222_1': 'bbp057',
 'L4_BTC_dNAC222_1': 'bbp069',
 'L4_ChC_dNAC222_1': 'bbp072',
 'L4_LBC_dNAC222_1': 'bbp083',
 'L4_MC_dNAC222_1': 'bbp089',
 'L4_NBC_dNAC222_1': 'bbp093',
 'L4_SBC_dNAC222_1': 'bbp101',
 'L5_ChC_dNAC222_1': 'bbp115',
 'L5_LBC_dNAC222_1': 'bbp128',
 'L5_MC_dNAC222_1': 'bbp136',
 'L5_SBC_dNAC222_1': 'bbp151',
 'L6_ChC_dNAC222_1': 'bbp168',
 'L6_SBC_dNAC222_1': 'bbp204',
 'L23_BP_dSTUT214_1': 'bbp020',
 'L4_BP_dSTUT214_1': 'bbp063',
 'L4_LBC_dSTUT214_1': 'bbp084',
 'L5_BP_dSTUT214_1': 'bbp109',
 'L5_LBC_dSTUT214_1': 'bbp129',
 'L5_NBC_dSTUT214_1': 'bbp144',
 'L6_BP_dSTUT214_1': 'bbp162',
 'L6_NBC_dSTUT214_1': 'bbp197'}

# %%
len(mapping.keys())
# Out:
# 169

# %%
for file in os.listdir(directory):
    filename = os.fsdecode(file)
    file_name = "/Users/shivam/Desktop/neuron_analysos/analysis/TMD/cells_being_used/" + filename
    if (filename[:len(filename)-4] in mapping.keys()):
        neu = tmd.io.load_neuron(file_name)
        ph_all = tmd.methods.get_ph_neuron(neu, neurite_type='all')
        dist1 = tmd.analysis.distance_horizontal(ph_all,ph_all_base)
        actual_name= mapping[filename[:len(filename)-4]]
        distance_horizontal.append((actual_name, dist1))
        dist2 = tmd.analysis.distance_stepped(ph_all,ph_all_base)
        distance_stepped.append((actual_name, dist2))

# %%
tracked = {}
for val in distance_horizontal:
    tracked[val[0]] = val[1]

# %%
tracked
# Out:
# {'L6_DBC_cNAC187_1.swc': 400.0,
#  'L23_BP_cACint209_1.swc': 147.0,
#  'L6_MC_bSTUT213_1.swc': 1071.0,
#  'L6_NGC_cACint209_1.swc': 1304.0,
#  'L5_SBC_cACint209_1.swc': 1450.0,
#  'L4_ChC_cNAC187_1.swc': 2920.0,
#  'L23_SBC_bNAC219_1.swc': 1250.0,
#  'L6_BTC_cACint209_1.swc': 2360.0,
#  'L1_SLAC_cACint209_1.swc': 677.0,
#  'L23_NBC_cACint209_1.swc': 2948.0,
#  'L4_BTC_dNAC222_1.swc': 2652.0,
#  'L4_SBC_cACint209_1.swc': 2257.0,
#  'L5_MC_cNAC187_1.swc': 1353.0,
#  'L6_BP_cNAC187_1.swc': 559.0,
#  'L5_TTPC2_cADpyr232_1.swc': 2117.0,
#  'L4_SBC_dNAC222_1.swc': 2889.0,
#  'L23_BTC_bNAC219_1.swc': 2661.0,
#  'L5_NGC_bNAC219_1.swc': 1301.0,
#  'L5_BTC_cACint209_1.swc': 771.0,
#  'L6_DBC_bSTUT213_1.swc': 1645.0,
#  'L4_NGC_cACint209_1.swc': 3316.0,
#  'L23_LBC_cNAC187_1.swc': 1483.0,
#  'L6_NBC_dSTUT214_1.swc': 2123.0,
#  'L6_MC_cACint209_1.swc': 743.0,
#  'L5_STPC_cADpyr232_1.swc': 793.0,
#  'L6_NBC_cSTUT189_1.swc': 1985.0,
#  'L4_PC_cADpyr230_1.swc': 846.0,
#  'L6_SBC_cACint209_1.swc': 891.0,
#  'L5_NGC_cACint209_1.swc': 1357.0,
#  'L1_DAC_cNAC187_1.swc': 750.0,
#  'L4_BTC_cACint209_1.swc': 2505.0,
#  'L1_NGC-SA_cNAC187_1.swc': 2000.0,
#  'L23_MC_dNAC222_1.swc': 2402.0,
#  'L6_MC_bNAC219_1.swc': 516.0,
#  'L4_LBC_cACint209_1.swc': 2204.0,
#  'L5_BP_bNAC219_1.swc': 533.0,
#  'L5_NBC_cSTUT189_1.swc': 1833.0,
#  'L5_MC_cACint209_1.swc': 795.0,
#  'L23_NBC_bNAC219_1.swc': 1976.0,
#  'L6_LBC_cNAC187_1.swc': 2750.0,
#  'L5_ChC_cNAC187_1.swc': 2919.0,
#  'L5_LBC_cACint209_1.swc': 2568.0,
#  'L5_NBC_dSTUT214_1.swc': 1452.0,
#  'L5_DBC_bSTUT213_1.swc': 370.0,
#  'L1_SLAC_cNAC187_1.swc': 655.0,
#  'L5_SBC_dNAC222_1.swc': 1548.0,
#  'L5_MC_cSTUT189_1.swc': 1009.0,
#  'L4_NGC_bNAC219_1.swc': 2623.0,
#  'L6_BPC_cADpyr231_1.swc': 1197.0,
#  'L6_SBC_bNAC219_1.swc': 872.0,
#  'L4_NBC_dNAC222_1.swc': 3088.0,
#  'L4_NGC_cSTUT189_1.swc': 2885.0,
#  'L6_NBC_cIR216_1.swc': 2948.0,
#  'L4_DBC_cNAC187_1.swc': 626.0,
#  'L4_MC_cNAC187_1.swc': 2394.0,
#  'L5_LBC_cNAC187_1.swc': 2347.0,
#  'L6_DBC_cIR216_1.swc': 1710.0,
#  'L6_ChC_cNAC187_1.swc': 2788.0,
#  'L23_NGC_bNAC219_1.swc': 2885.0,
#  'L23_NBC_dNAC222_1.swc': 1836.0,
#  'L23_LBC_cACint209_1.swc': 1354.0,
#  'L23_MC_bNAC219_1.swc': 1467.0,
#  'L6_NBC_bSTUT213_1.swc': 3750.0,
#  'L6_SBC_dNAC222_1.swc': 893.0,
#  'L6_TPC_L4_cADpyr231_1.swc': 950.0,
#  'L1_HAC_bNAC219_1.swc': 1565.0,
#  'L4_LBC_cSTUT189_1.swc': 1700.0,
#  'L23_NBC_cIR216_1.swc': 3209.0,
#  'L5_BP_cACint209_1.swc': 673.0,
#  'L4_LBC_dSTUT214_1.swc': 1253.0,
#  'L5_SBC_bNAC219_1.swc': 1377.0,
#  'L1_NGC-DA_bNAC219_1.swc': 1515.0,
#  'L5_DBC_cNAC187_1.swc': 1087.0,
#  'L4_NBC_cACint209_1.swc': 1867.0,
#  'L5_MC_bSTUT213_1.swc': 795.0,
#  'L6_BP_cACint209_1.swc': 560.0,
#  'L23_SBC_dNAC222_1.swc': 1552.0,
#  'L4_LBC_cNAC187_1.swc': 1650.0,
#  'L23_BP_cNAC187_1.swc': 152.0,
#  'L23_SBC_cACint209_1.swc': 3780.0,
#  'L5_NBC_cACint209_1.swc': 1692.0,
#  'L5_UTPC_cADpyr232_1.swc': 1299.0,
#  'L4_BP_bNAC219_1.swc': 721.0,
#  'L5_NBC_bSTUT213_1.swc': 1801.0,
#  'L23_BTC_cACint209_1.swc': 2815.0,
#  'L6_NGC_bNAC219_1.swc': 1314.0,
#  'L23_ChC_cNAC187_1.swc': 3193.0,
#  'L6_NBC_cACint209_1.swc': 3044.0,
#  'L23_MC_cACint209_1.swc': 562.0,
#  'L4_SBC_bNAC219_1.swc': 2876.0,
#  'L23_NGC_cACint209_1.swc': 3104.0,
#  'L23_LBC_dNAC222_1.swc': 1483.0,
#  'L6_LBC_cSTUT189_1.swc': 1876.0,
#  'L6_NGC_cNAC187_1.swc': 1184.0,
#  'L1_NGC-DA_cSTUT189_1.swc': 1458.0,
#  'L6_MC_cIR216_1.swc': 1194.0,
#  'L5_NBC_cNAC187_1.swc': 1572.0,
#  'L6_IPC_cADpyr231_1.swc': 861.0,
#  'L23_NGC_cSTUT189_1.swc': 3255.0,
#  'L1_NGC-DA_cACint209_1.swc': 1504.0,
#  'L23_BP_dSTUT214_1.swc': 136.0,
#  'L4_ChC_dNAC222_1.swc': 2971.0,
#  'L4_BP_cNAC187_1.swc': 694.0,
#  'L5_DBC_cIR216_1.swc': 401.0,
#  'L23_ChC_cACint209_1.swc': 3032.0,
#  'L23_BP_bNAC219_1.swc': 141.0,
#  'L5_MC_dNAC222_1.swc': 1019.0,
#  'L5_LBC_cIR216_1.swc': 2378.0,
#  'L4_SP_cADpyr230_1.swc': 513.0,
#  'L4_BTC_cNAC187_1.swc': 2432.0,
#  'L5_DBC_bNAC219_1.swc': 1024.0,
#  'L23_DBC_cACint209_1.swc': 556.0,
#  'L4_NBC_cIR216_1.swc': 3142.0,
#  'L1_NGC-DA_cNAC187_1.swc': 2470.0,
#  'L23_PC_cADpyr229_1.swc': 845.0,
#  'L6_BP_dSTUT214_1.swc': 619.0,
#  'L6_TPC_L1_cADpyr231_1.swc': 1281.0,
#  'L1_HAC_cNAC187_1.swc': 1160.0,
#  'L4_NBC_cNAC187_1.swc': 3370.0,
#  'L5_LBC_dSTUT214_1.swc': 1825.0,
#  'L5_ChC_dNAC222_1.swc': 2879.0,
#  'L4_BP_cACint209_1.swc': 721.0,
#  'L23_MC_cNAC187_1.swc': 1592.0,
#  'L23_NGC_cNAC187_1.swc': 3023.0,
#  'L4_MC_bNAC219_1.swc': 1237.0,
#  'L5_TTPC1_cADpyr232_1.swc': 2867.0,
#  'L4_DBC_bNAC219_1.swc': 597.0,
#  'L5_BTC_cNAC187_1.swc': 744.0,
#  'L5_LBC_cSTUT189_1.swc': 1377.0,
#  'L4_BTC_bSTUT213_1.swc': 2495.0,
#  'L5_BP_dSTUT214_1.swc': 660.0,
#  'L4_DBC_bSTUT213_1.swc': 626.0,
#  'L4_NGC_cNAC187_1.swc': 2657.0,
#  'L4_MC_cACint209_1.swc': 1237.0,
#  'L1_HAC_cIR216_1.swc': 1378.0,
#  'L23_DBC_bNAC219_1.swc': 598.0,
#  'L6_ChC_dNAC222_1.swc': 2939.0,
#  'L5_LBC_dNAC222_1.swc': 2017.0,
#  'L1_SLAC_bNAC219_1.swc': 776.0,
#  'L6_LBC_bSTUT213_1.swc': 1346.0,
#  'L5_NGC_cSTUT189_1.swc': 1324.0,
#  'L4_MC_dNAC222_1.swc': 2394.0,
#  'L6_LBC_bNAC219_1.swc': 2248.0,
#  'L4_DBC_cIR216_1.swc': 657.0,
#  'L6_MC_cNAC187_1.swc': 516.0,
#  'L5_BP_cNAC187_1.swc': 608.0,
#  'L6_BTC_cNAC187_1.swc': 2338.0,
#  'L6_UTPC_cADpyr231_1.swc': 738.0,
#  'L23_NBC_cNAC187_1.swc': 2080.0,
#  'L6_DBC_cACint209_1.swc': 1762.0,
#  'L4_BP_dSTUT214_1.swc': 625.0,
#  'L23_ChC_dNAC222_1.swc': 3104.0,
#  'L1_DAC_bNAC219_1.swc': 2504.0,
#  'L23_LBC_cSTUT189_1.swc': 1237.0,
#  'L5_NGC_cNAC187_1.swc': 1073.0,
#  'L6_ChC_cACint209_1.swc': 3093.0,
#  'L23_LBC_bNAC219_1.swc': 1254.0,
#  'L6_NBC_cNAC187_1.swc': 3382.0,
#  'L6_NGC_cSTUT189_1.swc': 1236.0,
#  'L5_NBC_cIR216_1.swc': 1572.0,
#  'L23_BTC_cNAC187_1.swc': 2477.0,
#  'L4_LBC_dNAC222_1.swc': 1270.0,
#  'L6_BP_bNAC219_1.swc': 730.0,
#  'L4_DBC_cACint209_1.swc': 583.0,
#  'L5_ChC_cACint209_1.swc': 3033.0,
#  'L1_DLAC_cNAC187_1.swc': 1744.0,
#  'L6_DBC_bNAC219_1.swc': 1705.0,
#  'L4_ChC_cACint209_1.swc': 2979.0,
#  'L5_DBC_cACint209_1.swc': 1041.0,
#  'bbp175': 400.0,
#  'bbp018': 147.0,
#  'bbp186': 1071.0,
#  'bbp199': 1304.0,
#  'bbp150': 1450.0,
#  'bbp071': 2920.0,
#  'bbp055': 1250.0,
#  'bbp164': 2360.0,
#  'bbp013': 677.0,
#  'bbp046': 2948.0,
#  'bbp069': 2652.0,
#  'bbp100': 2257.0,
#  'bbp134': 1353.0,
#  'bbp161': 559.0,
#  'bbp154': 2117.0,
#  'bbp101': 2889.0,
#  'bbp023': 2661.0,
#  'bbp145': 1301.0,
#  'bbp111': 771.0,
#  'bbp172': 1645.0,
#  'bbp095': 3316.0,
#  'bbp036': 1483.0,
#  'bbp197': 2123.0,
#  'bbp187': 743.0,
#  'bbp152': 793.0,
#  'bbp196': 1985.0,
#  'bbp098': 846.0,
#  'bbp203': 891.0,
#  'bbp146': 1357.0,
#  'bbp002': 750.0,
#  'bbp067': 2505.0,
#  'bbp011': 2000.0,
#  'bbp043': 2402.0,
#  'bbp185': 516.0,
#  'bbp080': 2204.0,
#  'bbp106': 533.0,
#  'bbp143': 1833.0,
#  'bbp133': 795.0,
#  'bbp045': 1976.0,
#  'bbp181': 2750.0,
#  'bbp114': 2919.0,
#  'bbp124': 2568.0,
#  'bbp144': 1452.0,
#  'bbp119': 370.0,
#  'bbp014': 655.0,
#  'bbp151': 1548.0,
#  'bbp135': 1009.0,
#  'bbp094': 2623.0,
#  'bbp156': 1197.0,
#  'bbp202': 872.0,
#  'bbp093': 3088.0,
#  'bbp097': 2885.0,
#  'bbp194': 2948.0,
#  'bbp079': 626.0,
#  'bbp088': 2394.0,
#  'bbp126': 2347.0,
#  'bbp174': 1710.0,
#  'bbp167': 2788.0,
#  'bbp050': 2885.0,
#  'bbp049': 1836.0,
#  'bbp035': 1354.0,
#  'bbp040': 1467.0,
#  'bbp192': 3750.0,
#  'bbp204': 893.0,
#  'bbp206': 950.0,
#  'bbp004': 1565.0,
#  'bbp082': 1700.0,
#  'bbp047': 3209.0,
#  'bbp107': 673.0,
#  'bbp084': 1253.0,
#  'bbp149': 1377.0,
#  'bbp007': 1515.0,
#  'bbp122': 1087.0,
#  'bbp090': 1867.0,
#  'bbp132': 795.0,
#  'bbp160': 560.0,
#  'bbp057': 1552.0,
#  'bbp081': 1650.0,
#  'bbp019': 152.0,
#  'bbp056': 3780.0,
#  'bbp140': 1692.0,
#  'bbp155': 1299.0,
#  'bbp060': 721.0,
#  'bbp139': 1801.0,
#  'bbp024': 2815.0,
#  'bbp198': 1314.0,
#  'bbp027': 3193.0,
#  'bbp193': 3044.0,
#  'bbp041': 562.0,
#  'bbp099': 2876.0,
#  'bbp051': 3104.0,
#  'bbp038': 1483.0,
#  'bbp182': 1876.0,
#  'bbp200': 1184.0,
#  'bbp010': 1458.0,
#  'bbp188': 1194.0,
#  'bbp142': 1572.0,
#  'bbp176': 861.0,
#  'bbp053': 3255.0,
#  'bbp008': 1504.0,
#  'bbp020': 136.0,
#  'bbp072': 2971.0,
#  'bbp062': 694.0,
#  'bbp121': 401.0,
#  'bbp026': 3032.0,
#  'bbp017': 141.0,
#  'bbp136': 1019.0,
#  'bbp125': 2378.0,
#  'bbp102': 513.0,
#  'bbp068': 2432.0,
#  'bbp118': 1024.0,
#  'bbp032': 556.0,
#  'bbp091': 3142.0,
#  'bbp009': 2470.0,
#  'bbp054': 845.0,
#  'bbp162': 619.0,
#  'bbp205': 1281.0,
#  'bbp006': 1160.0,
#  'bbp092': 3370.0,
#  'bbp129': 1825.0,
#  'bbp115': 2879.0,
#  'bbp061': 721.0,
#  'bbp042': 1592.0,
#  'bbp052': 3023.0,
#  'bbp086': 1237.0,
#  'bbp153': 2867.0,
#  'bbp075': 597.0,
#  'bbp112': 744.0,
#  'bbp127': 1377.0,
#  'bbp066': 2495.0,
#  'bbp109': 660.0,
#  'bbp076': 626.0,
#  'bbp096': 2657.0,
#  'bbp087': 1237.0,
#  'bbp005': 1378.0,
#  'bbp031': 598.0,
#  'bbp168': 2939.0,
#  'bbp128': 2017.0,
#  'bbp012': 776.0,
#  'bbp180': 1346.0,
#  'bbp148': 1324.0,
#  'bbp089': 2394.0,
#  'bbp179': 2248.0,
#  'bbp078': 657.0,
#  'bbp189': 516.0,
#  'bbp108': 608.0,
#  'bbp165': 2338.0,
#  'bbp207': 738.0,
#  'bbp048': 2080.0,
#  'bbp173': 1762.0,
#  'bbp063': 625.0,
#  'bbp028': 3104.0,
#  'bbp001': 2504.0,
#  'bbp037': 1237.0,
#  'bbp147': 1073.0,
#  'bbp166': 3093.0,
#  'bbp034': 1254.0,
#  'bbp195': 3382.0,
#  'bbp201': 1236.0,
#  'bbp141': 1572.0,
#  'bbp025': 2477.0,
#  'bbp083': 1270.0,
#  'bbp159': 730.0,
#  'bbp077': 583.0,
#  'bbp113': 3033.0,
#  'bbp003': 1744.0,
#  'bbp171': 1705.0,
#  'bbp070': 2979.0,
#  'bbp120': 1041.0}

# %%
distance_horizontal.sort(key=lambda x: x[1])
distance_stepped.sort(key=lambda x: x[1])

# %%
indices = [0, 103, 206]
for i in indices:
    filename = distance_horizontal[i][0]
    print(filename, i)
    file_name = "/Users/shivam/Desktop/neuron_analysos/analysis/TMD/cells_being_used/" + filename
    neu = tmd.io.load_neuron(file_name)
    tree = neu.neurites[0]
    ph1 = tmd.methods.get_persistence_diagram(tree)
    ph_neu = tmd.methods.get_ph_neuron(neu)
    view.neuron(neu)
    ph_all = tmd.methods.get_ph_neuron(neu, neurite_type='all')
    plot.barcode(ph_all)
# Out:
# L23_BP_dSTUT214_1.swc 0
# L1_NGC-DA_cSTUT189_1.swc 103
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:146: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = fig.add_subplot(subplot, **params)
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:146: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = fig.add_subplot(subplot, **params)
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:146: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = fig.add_subplot(subplot, **params)
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:146: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = fig.add_subplot(subplot, **params)
# L23_SBC_cACint209_1.swc 206
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:146: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = fig.add_subplot(subplot, **params)
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:146: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = fig.add_subplot(subplot, **params)

# %%
indices = [0, 103, 206]
for i in indices:
    filename = distance_stepped[i][0]
    print(filename, i)
    file_name = "//Users/shivam/Desktop/neuron_analysos/analysis/TMD/cells_being_used/" + filename
    neu = tmd.io.load_neuron(file_name)
    tree = neu.neurites[0]
    ph1 = tmd.methods.get_persistence_diagram(tree)
    ph_neu = tmd.methods.get_ph_neuron(neu)
    view.neuron(neu)
    ph_all = tmd.methods.get_ph_neuron(neu, neurite_type='all')
    plot.barcode(ph_all)
# Out:
# L23_BP_cACint209_1.swc 0
# L23_LBC_cACint209_1.swc 103
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:146: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = fig.add_subplot(subplot, **params)
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:146: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = fig.add_subplot(subplot, **params)
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:146: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = fig.add_subplot(subplot, **params)
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:146: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = fig.add_subplot(subplot, **params)
# L23_MC_dNAC222_1.swc 206
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:146: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = fig.add_subplot(subplot, **params)
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:146: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = fig.add_subplot(subplot, **params)

# %%
tracker = {}
for i in range(len(distance_horizontal)):
    curr_elem = distance_stepped[i]
    name = curr_elem[0]
    value = curr_elem[1]
    m_type = name[name.find("_")+1:name.find("_")+1+name[name.find("_")+1:].find("_")]
    curr_elems = tracker.get(m_type, [[], []])
    curr_elems[0].append(name)
    curr_elems[1].append(value)
    tracker[m_type] = curr_elems

# %%
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import re
tracker = {}
for i in range(len(distance_horizontal)):
    curr_elem = distance_stepped[i]
    name = curr_elem[0]
    value = curr_elem[1]
    second_dash = name[name.find("_")+1+name[name.find("_")+1:].find("_")+1:]
    ind = re.search(r"\d", second_dash)
    e_type = second_dash[:ind.start()]
    curr_elems = tracker.get(e_type, [[], []])
    curr_elems[0].append(name)
    curr_elems[1].append(value)
    tracker[e_type] = curr_elems

# %%
elems = []
for key in tracker.keys():
    leastcomplex = tracker[key][0][0]
    mostcomplex = tracker[key][0][len(tracker[key][0])-1]
    file_name = "//Users/shivam/Desktop/neuron_analysos/analysis/TMD/cells_being_used/" + leastcomplex
    neu = tmd.io.load_neuron(file_name)
    file_name = "//Users/shivam/Desktop/neuron_analysos/analysis/TMD/cells_being_used/" + mostcomplex
    neu1 = tmd.io.load_neuron(file_name)
    elems.append(neu)
    elems.append(neu1)

# %%
for key in tracker.keys():
    print("E-type:{}".format(key))
    leastcomplex = tracker[key][0][0]
    mostcomplex = tracker[key][0][len(tracker[key][0])-1]
    print("least complex")
    file_name = "//Users/shivam/Desktop/neuron_analysos/analysis/TMD/cells_being_used/" + leastcomplex
    neu = tmd.io.load_neuron(file_name)
    tree = neu.neurites[0]
    ph1 = tmd.methods.get_persistence_diagram(tree)
    ph_neu = tmd.methods.get_ph_neuron(neu)
    view.neuron(neu)
    print("most complex")
    file_name = "//Users/shivam/Desktop/neuron_analysos/analysis/TMD/cells_being_used/" + mostcomplex
    neu = tmd.io.load_neuron(file_name)
    tree = neu.neurites[0]
    ph1 = tmd.methods.get_persistence_diagram(tree)
    ph_neu = tmd.methods.get_ph_neuron(neu)
    view.neuron(neu)
# Out:
# E-type:cACint
# least complex
# most complex
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:146: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = fig.add_subplot(subplot, **params)
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:146: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = fig.add_subplot(subplot, **params)
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:146: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = fig.add_subplot(subplot, **params)
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:146: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = fig.add_subplot(subplot, **params)
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:146: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = fig.add_subplot(subplot, **params)
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:146: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = fig.add_subplot(subplot, **params)
# E-type:bNAC
# least complex
# most complex
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:146: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = fig.add_subplot(subplot, **params)
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:146: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = fig.add_subplot(subplot, **params)
# E-type:dSTUT
# least complex
# most complex
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:146: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = fig.add_subplot(subplot, **params)
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:146: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = fig.add_subplot(subplot, **params)
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:146: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = fig.add_subplot(subplot, **params)
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:146: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = fig.add_subplot(subplot, **params)
# E-type:cNAC
# least complex
# most complex
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:146: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = fig.add_subplot(subplot, **params)
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:146: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = fig.add_subplot(subplot, **params)
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:146: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = fig.add_subplot(subplot, **params)
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:146: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = fig.add_subplot(subplot, **params)
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:146: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = fig.add_subplot(subplot, **params)
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:146: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = fig.add_subplot(subplot, **params)
# E-type:bAC
# least complex
# most complex
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:146: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = fig.add_subplot(subplot, **params)
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:146: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = fig.add_subplot(subplot, **params)
# E-type:bIR
# least complex
# most complex
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:146: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = fig.add_subplot(subplot, **params)
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:146: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = fig.add_subplot(subplot, **params)
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:146: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = fig.add_subplot(subplot, **params)
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:146: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = fig.add_subplot(subplot, **params)
# E-type:bSTUT
# least complex
# most complex
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:146: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = fig.add_subplot(subplot, **params)
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:146: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = fig.add_subplot(subplot, **params)
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:146: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = fig.add_subplot(subplot, **params)
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:146: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = fig.add_subplot(subplot, **params)
# E-type:cIR
# least complex
# most complex
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:146: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = fig.add_subplot(subplot, **params)
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:146: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = fig.add_subplot(subplot, **params)
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:146: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = fig.add_subplot(subplot, **params)
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:146: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = fig.add_subplot(subplot, **params)
# E-type:cADpyr
# least complex
# most complex
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:146: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = fig.add_subplot(subplot, **params)
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:146: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = fig.add_subplot(subplot, **params)
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:146: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = fig.add_subplot(subplot, **params)
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:146: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = fig.add_subplot(subplot, **params)
# E-type:L
# least complex
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:146: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = fig.add_subplot(subplot, **params)
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:146: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = fig.add_subplot(subplot, **params)
# most complex
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:146: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = fig.add_subplot(subplot, **params)
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:146: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = fig.add_subplot(subplot, **params)
# E-type:cSTUT
# least complex
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:129: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure()
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:146: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = fig.add_subplot(subplot, **params)
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:146: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = fig.add_subplot(subplot, **params)
# most complex
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:129: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure()
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:146: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = fig.add_subplot(subplot, **params)
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:146: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = fig.add_subplot(subplot, **params)
# E-type:dNAC
# least complex
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:129: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure()
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:146: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = fig.add_subplot(subplot, **params)
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:146: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = fig.add_subplot(subplot, **params)
# most complex
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:129: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure()
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:146: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = fig.add_subplot(subplot, **params)
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:146: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = fig.add_subplot(subplot, **params)

# %%
curr_val = tracker["cNAC"]
for filename in curr_val[0]:
    file_name = "//Users/shivam/Desktop/neuron_analysos/analysis/TMD/cells_being_used/" + filename
    neu = tmd.io.load_neuron(file_name)
    tree = neu.neurites[0]
    ph1 = tmd.methods.get_persistence_diagram(tree)
    ph_neu = tmd.methods.get_ph_neuron(neu)
    view.neuron(neu)
    ph_all = tmd.methods.get_ph_neuron(neu, neurite_type='all')
    plot.barcode(ph_all)
# Out:
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:146: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = fig.add_subplot(subplot, **params)
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:146: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = fig.add_subplot(subplot, **params)
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:146: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = fig.add_subplot(subplot, **params)
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:146: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = fig.add_subplot(subplot, **params)
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:146: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = fig.add_subplot(subplot, **params)
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:146: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = fig.add_subplot(subplot, **params)
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:146: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = fig.add_subplot(subplot, **params)
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:146: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = fig.add_subplot(subplot, **params)
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:146: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = fig.add_subplot(subplot, **params)
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:146: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = fig.add_subplot(subplot, **params)
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:146: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = fig.add_subplot(subplot, **params)
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:146: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = fig.add_subplot(subplot, **params)
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:146: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = fig.add_subplot(subplot, **params)
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:146: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = fig.add_subplot(subplot, **params)
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:146: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = fig.add_subplot(subplot, **params)
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:146: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = fig.add_subplot(subplot, **params)
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:146: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = fig.add_subplot(subplot, **params)
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:146: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = fig.add_subplot(subplot, **params)
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:146: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = fig.add_subplot(subplot, **params)
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:146: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = fig.add_subplot(subplot, **params)
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:129: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure()
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:146: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = fig.add_subplot(subplot, **params)
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:146: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = fig.add_subplot(subplot, **params)
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:129: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure()
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:129: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure()
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:146: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = fig.add_subplot(subplot, **params)
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:146: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = fig.add_subplot(subplot, **params)
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:129: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure()
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:129: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure()
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:146: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = fig.add_subplot(subplot, **params)
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:146: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = fig.add_subplot(subplot, **params)
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:129: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure()
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:129: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure()
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:146: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = fig.add_subplot(subplot, **params)
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:146: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = fig.add_subplot(subplot, **params)
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:129: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure()
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:129: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure()
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:146: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = fig.add_subplot(subplot, **params)
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:146: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = fig.add_subplot(subplot, **params)
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:129: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure()
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:129: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure()
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:146: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = fig.add_subplot(subplot, **params)
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:146: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = fig.add_subplot(subplot, **params)
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:129: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure()
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:129: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure()
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:146: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = fig.add_subplot(subplot, **params)
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:146: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = fig.add_subplot(subplot, **params)
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:129: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure()
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:129: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure()
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:146: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = fig.add_subplot(subplot, **params)
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:146: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = fig.add_subplot(subplot, **params)
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:129: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure()
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:129: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure()
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:146: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = fig.add_subplot(subplot, **params)
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:146: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = fig.add_subplot(subplot, **params)
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:129: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure()
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:129: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure()
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:146: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = fig.add_subplot(subplot, **params)
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:146: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = fig.add_subplot(subplot, **params)
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:129: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure()
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:129: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure()
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:146: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = fig.add_subplot(subplot, **params)
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:146: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = fig.add_subplot(subplot, **params)
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:129: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure()
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:129: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure()
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:146: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = fig.add_subplot(subplot, **params)
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:146: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = fig.add_subplot(subplot, **params)
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:129: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure()
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:129: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure()
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:146: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = fig.add_subplot(subplot, **params)
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:146: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = fig.add_subplot(subplot, **params)
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:129: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure()
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:129: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure()
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:146: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = fig.add_subplot(subplot, **params)
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:146: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = fig.add_subplot(subplot, **params)
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:129: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure()
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:129: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure()
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:146: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = fig.add_subplot(subplot, **params)
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:146: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = fig.add_subplot(subplot, **params)
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:129: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure()
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:129: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure()
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:146: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = fig.add_subplot(subplot, **params)
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:146: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = fig.add_subplot(subplot, **params)
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:129: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure()
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:129: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure()
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:146: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = fig.add_subplot(subplot, **params)
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:146: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = fig.add_subplot(subplot, **params)
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:129: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure()
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:129: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure()
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:146: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = fig.add_subplot(subplot, **params)
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:146: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = fig.add_subplot(subplot, **params)
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:129: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure()
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:129: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure()
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:146: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = fig.add_subplot(subplot, **params)
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:146: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = fig.add_subplot(subplot, **params)
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:129: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure()
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:129: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure()
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:146: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = fig.add_subplot(subplot, **params)
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:146: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = fig.add_subplot(subplot, **params)
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:129: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure()
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:129: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure()
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:146: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = fig.add_subplot(subplot, **params)
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:146: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = fig.add_subplot(subplot, **params)
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:129: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure()
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:129: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure()
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:146: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = fig.add_subplot(subplot, **params)
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:146: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = fig.add_subplot(subplot, **params)
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:129: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure()
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:129: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure()
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:146: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = fig.add_subplot(subplot, **params)
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:146: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = fig.add_subplot(subplot, **params)
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:129: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure()
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:129: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure()
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:146: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = fig.add_subplot(subplot, **params)
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:146: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = fig.add_subplot(subplot, **params)
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:129: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure()
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:129: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure()
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:146: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = fig.add_subplot(subplot, **params)
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:146: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = fig.add_subplot(subplot, **params)
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:129: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure()
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:129: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure()
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:146: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = fig.add_subplot(subplot, **params)
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:146: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = fig.add_subplot(subplot, **params)
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:129: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure()
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:129: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure()
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:146: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = fig.add_subplot(subplot, **params)
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:146: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = fig.add_subplot(subplot, **params)
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:129: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure()

# %%
fig, ax = plt.subplots()
fig.set_size_inches(50, 25, forward = True)
leg = []
for key in tracker.keys():
    x_vals = tracker[key][0]
    y_vals = tracker[key][1]
    key = plt.scatter(x_vals,y_vals)
    plt.xticks(rotation=90)
    leg.append(key)
plt.legend((leg),('BP', 'DBC', 'SP', 'MC', 'SLAC', 'BTC', 'UTPC', 'DAC', 'STPC', 'PC', 'IPC', 'SBC', 'TPC', 'SS', 'NGC', 'HAC', 'BPC', 'LBC', 'NBC', 'NGC-DA', 'DLAC', 'NGC-SA', 'TTPC2', 'ChC', 'TTPC1'),scatterpoints=1,loc='top left',ncol=3,fontsize=20)
plt.title("Cell Complexities ranked according to TMD stepped distance", fontsize = 40)
plt.savefig('output.png')
# Out:
# <ipython-input-14-07262a5cee7a>:10: MatplotlibDeprecationWarning: Unrecognized location 'top left'. Falling back on 'best'; valid locations are
# 	best
# 	upper right
# 	upper left
# 	lower left
# 	lower right
# 	right
# 	center left
# 	center right
# 	lower center
# 	upper center
# 	center
# This will raise an exception in 3.3.
#   plt.legend((leg),('BP', 'DBC', 'SP', 'MC', 'SLAC', 'BTC', 'UTPC', 'DAC', 'STPC', 'PC', 'IPC', 'SBC', 'TPC', 'SS', 'NGC', 'HAC', 'BPC', 'LBC', 'NBC', 'NGC-DA', 'DLAC', 'NGC-SA', 'TTPC2', 'ChC', 'TTPC1'),scatterpoints=1,loc='top left',ncol=3,fontsize=20)

# %%
fig, ax = plt.subplots()
fig.set_size_inches(50, 25, forward = True)
leg = []
for key in tracker.keys():
    x_vals = tracker[key][0]
    y_vals = tracker[key][1]
    key = plt.scatter(x_vals,y_vals)
    plt.xticks(rotation=90)
    leg.append(key)
plt.legend((leg),('cACint', 'bNAC', 'dSTUT', 'cNAC', 'bAC', 'bIR', 'bSTUT', 'cIR', 'cADpyr', 'L', 'cSTUT', 'dNAC'),scatterpoints=1,loc='top left',ncol=3,fontsize=20)
plt.title("Cell Complexities ranked according to TMD stepped distance", fontsize = 40)
plt.savefig('output.png')
# Out:
# <ipython-input-35-f5d3505b341b>:10: MatplotlibDeprecationWarning: Unrecognized location 'top left'. Falling back on 'best'; valid locations are
# 	best
# 	upper right
# 	upper left
# 	lower left
# 	lower right
# 	right
# 	center left
# 	center right
# 	lower center
# 	upper center
# 	center
# This will raise an exception in 3.3.
#   plt.legend((leg),('cACint', 'bNAC', 'dSTUT', 'cNAC', 'bAC', 'bIR', 'bSTUT', 'cIR', 'cADpyr', 'L', 'cSTUT', 'dNAC'),scatterpoints=1,loc='top left',ncol=3,fontsize=20)

# %%
names = list(names)
names
# Out:
# ['BP',
#  'DBC',
#  'SP',
#  'MC',
#  'SLAC',
#  'BTC',
#  'UTPC',
#  'DAC',
#  'STPC',
#  'PC',
#  'IPC',
#  'SBC',
#  'TPC',
#  'SS',
#  'NGC',
#  'HAC',
#  'BPC',
#  'LBC',
#  'NBC',
#  'NGC-DA',
#  'DLAC',
#  'NGC-SA',
#  'TTPC2',
#  'ChC',
#  'TTPC1']
