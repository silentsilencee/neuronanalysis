# %%
import morphio
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-a4777ebf071c> in <module>()
# ----> 1 import morphio
#
# ModuleNotFoundError: No module named 'morphio'

# %%
filename = '/Users/shivam/Desktop/TMD/Cells/dend-C060114A2_axon-C060109A2.asc'
neu = tmd.io.load_neuron(filename)
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-3-5e3fc30efaa8> in <module>
#       1 filename = '/Users/shivam/Desktop/TMD/Cells/dend-C060114A2_axon-C060109A2.asc'
# ----> 2 neu = tmd.io.load_neuron(filename)
#
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/io/io.py in load_neuron(input_file, line_delimiter, soma_type, tree_types, remove_duplicates)
#      76
#      77     try:
# ---> 78         soma_ids = _np.where(_np.transpose(data)[1] == soma_index)[0]
#      79     except IndexError:
#      80         raise LoadNeuronError('Soma points not in the expected format')
#
# UnboundLocalError: local variable 'data' referenced before assignment

# %%
tree = neu.neurites[0]
ph = tmd.methods.get_persistence_diagram(tree)

# Step 4: Extract the ph diagram of a neuron's trees
ph_neu = tmd.methods.get_ph_neuron(neu)

# Step 5: Extract the ph diagram of a neuron's trees,
# depending on the neurite_type
ph_apical = tmd.methods.get_ph_neuron(neu, neurite_type='all')
#ph_axon = tmd.methods.get_ph_neuron(neu, neurite_type='axon')
#ph_basal = tmd.methods.get_ph_neuron(neu, neurite_type='basal')

# %%
# Step 6: Plot the extracted topological data with three different ways
from tmd.view import view, plot

# Visualize the neuron
view.neuron(neu)

# Visualize a selected neurite type or multiple of them
view.neuron(neu, neurite_type=['apical'])

# Visualize the persistence diagram
plot.diagram(ph_apical)

# Visualize the persistence barcode
plot.barcode(ph_apical)

# Visualize the persistence image
plot.persistence_image(ph_apical)
# Out:
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:146: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = fig.add_subplot(subplot, **params)
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:146: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = fig.add_subplot(subplot, **params)
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:146: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = fig.add_subplot(subplot, **params)
# (array([[8.78071180e-01, 8.73797913e-01, 8.61090701e-01, ...,
#          7.20383116e-20, 3.14360703e-20, 1.35739094e-20],
#         [9.00006780e-01, 9.02463697e-01, 8.96146775e-01, ...,
#          1.86799495e-19, 8.22773956e-20, 3.58581779e-20],
#         [9.13977535e-01, 9.23441631e-01, 9.23969430e-01, ...,
#          4.79104821e-19, 2.12996702e-19, 9.36934872e-20],
#         ...,
#         [3.99081123e-02, 3.89504502e-02, 3.75629396e-02, ...,
#          1.05925561e-01, 1.06872427e-01, 1.07237377e-01],
#         [4.05729106e-02, 3.99632448e-02, 3.88938623e-02, ...,
#          9.96697799e-02, 1.00947059e-01, 1.01728012e-01],
#         [4.07969600e-02, 4.05532527e-02, 3.98308257e-02, ...,
#          9.32422012e-02, 9.47561210e-02, 9.58583062e-02]]),
#  (<Figure size 432x288 with 1 Axes>,
#   <matplotlib.axes._subplots.AxesSubplot at 0x1027c2bb0>))

# %%
filename = '/Users/shivam/Desktop/TMD/TMD/tests/data/valid/sample.swc'
neu1 = tmd.io.load_neuron(filename)

# %%
tree = neu1.neurites[0]
ph1 = tmd.methods.get_persistence_diagram(tree)
ph_neu = tmd.methods.get_ph_neuron(neu1)

# %%
view.neuron(neu1)
ph_apical = tmd.methods.get_ph_neuron(neu1, neurite_type='all')
plot.barcode(ph_apical)
# Out:
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:146: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = fig.add_subplot(subplot, **params)
# /opt/anaconda3/envs/TMD/lib/python3.8/site-packages/tmd/view/common.py:146: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = fig.add_subplot(subplot, **params)
# (<Figure size 432x288 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x12044ba30>)

# %%
tmd.analysis.distance_horizontal(ph,ph1)
# Out:
# 109.0

# %%
tmd.analysis.distance_stepped(ph,ph1)
# Out:
# 5366.205568667745
